# %%
# data is from this link: https://www.data.gouv.fr/fr/datasets/5bf39f229ce2e77b7d0059b6/#/resources

# %%
import pandas

# %%
df = pandas.read_excel("./Data/conso-epci-annuelle.xlsx", nrows=2000, skiprows=1)

# %%
df
# Out:
#       annee  code_epci                         libelle_epci code_departements  \
# 0      2021  240700302             CC du Pays Beaume-Drobie                 7
# 1      2021  240700716                       CC du Val d'Ay                 7
# 2      2021  240700864  CC du Rhône aux Gorges de l'Ardèche                 7
# 3      2021  240800821            CC Ardenne,Rives de Meuse                 8
# 4      2021  241000405      CC de la Région de Bar-sur-Aube                10
# ...     ...        ...                                  ...               ...
# 1995   2020  243100781               CC de la Save au Touch                31
# 1996   2015  200065886         CA Loire Forez Agglomération                42
# 1997   2020  243200391            CC de la Lomagne Gersoise                32
# 1998   2015  200065894                      CC de Forez-Est                42
# 1999   2020  243200417                    CC de la Tenarèze                32
#
# ...

# %%
df["annee"].unique()
# Out:
# array([2021, 2022, 2020, 2015, 2019, 2016, 2018, 2014, 2013, 2017])

# %% [markdown]
# # Take only 2021

# %%
df2021 = df.loc[df["annee"] == 2021]
df2021.shape
# Out:
# (222, 29)

# %%
df2021.columns
# Out:
# Index(['annee', 'code_epci', 'libelle_epci', 'code_departements',
#        'libelle_departements', 'code_regions', 'libelle_regions', 'consoa',
#        'consoi', 'consor', 'consot', 'consona', 'consototale', 'operateurs',
#        'e_consoa', 'e_consoi', 'e_consor', 'e_consot', 'e_consona',
#        'e_consototale', 'e_operateurs', 'g_consoa', 'g_consoi', 'g_consor',
#        'g_consot', 'g_consona', 'g_consototale', 'g_operateurs', 'centroid'],
#       dtype='object')

# %%
desired_column = ["annee", "code_epci", 'libelle_epci', 'code_departements',
       'libelle_departements', 'code_regions', 'libelle_regions', 'consototale', 'operateurs']

# %%
df2021 = df2021[desired_column]

# %%
df2021
# Out:
#       annee  code_epci                             libelle_epci  \
# 0      2021  240700302                 CC du Pays Beaume-Drobie
# 1      2021  240700716                           CC du Val d'Ay
# 2      2021  240700864      CC du Rhône aux Gorges de l'Ardèche
# 3      2021  240800821                CC Ardenne,Rives de Meuse
# 4      2021  241000405          CC de la Région de Bar-sur-Aube
# ...     ...        ...                                      ...
# 1964   2021  200090504              CA Coulommiers Pays de Brie
# 1966   2021  240100800              CC de Miribel et du Plateau
# 1968   2021  240100891           CC du Pays Bellegardien (CCPB)
# 1970   2021  240300558                   CC du Pays de Tronçais
# 1972   2021  240400440  CC Pays Forcalquier et Montagne de Lure
#
#      code_departements     libelle_departements code_regions  \
# 0                    7                  Ardèche           84
# 1                    7                  Ardèche           84
# ...

# %%
df2021["libelle_departements"].unique()
# Out:
# array(['Ardèche', 'Ardennes', 'Aube', 'Aveyron', 'Calvados', 'Charente',
#        'Cher', 'Corrèze', 'Corse-du-Sud', 'Haute-Corse', "Côte-d'Or",
#        'Creuse', 'Doubs', 'Finistère', "Finistère,Côtes-d'Armor", 'Gard',
#        'Haute-Garonne', 'Gironde', 'Gironde,Dordogne', 'Hérault',
#        'Gard,Hérault', 'Loire-Atlantique,Morbihan,Ille-et-Vilaine',
#        'Indre', 'Isère', 'Jura', 'Landes', 'Loir-et-Cher', 'Loire',
#        'Haute-Loire', 'Loire-Atlantique,Morbihan', 'Loiret', 'Lot',
#        'Lot-et-Garonne', 'Marne', 'Mayenne', 'Meurthe-et-Moselle',
#        'Morbihan', 'Moselle', 'Nièvre', 'Oise', 'Pas-de-Calais',
#        'Cantal,Puy-de-Dôme', 'Pyrénées-Atlantiques',
#        'Pyrénées-Orientales', 'Bas-Rhin', 'Haut-Rhin', 'Rhône',
#        'Haute-Saône', 'Saône-et-Loire', 'Sarthe', 'Savoie',
#        'Haute-Savoie', 'Deux-Sèvres', 'Tarn', 'Vendée', 'Vienne',
#        'Haute-Vienne', 'Yonne', 'Essonne', 'Martinique', 'La Réunion',
# ...

# %%
df2021["libelle_regions"].unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Grand Est', 'Occitanie', 'Normandie',
#        'Nouvelle-Aquitaine', 'Centre-Val de Loire', 'Corse',
#        'Bourgogne-Franche-Comté', 'Bretagne', 'Bretagne,Pays de la Loire',
#        'Pays de la Loire', 'Hauts-de-France', 'Île-de-France',
#        'Martinique', 'La Réunion', 'Guadeloupe',
#        "Provence-Alpes-Côte d'Azur", 'Mayotte',
#        'Normandie,Centre-Val de Loire',
#        'Bourgogne-Franche-Comté,Centre-Val de Loire'], dtype=object)

# %%
#df2021.groupby()
df2021_summary_ = df2021.groupby(by=["libelle_regions", "consototale"]).sum()

# %%
pandas.set_option('display.max_rows', 500)
df2021_summary_
# Out:
#                                                           annee  code_epci  \
# libelle_regions                             consototale
# Auvergne-Rhône-Alpes                        2.313372e+04   2021  240700716
#                                             3.301352e+04   2021  247300668
#                                             3.457608e+04   2021  200016905
#                                             3.939076e+04   2021  247300262
#                                             3.947210e+04   2021  247400047
#                                             4.873798e+04   2021  200039824
#                                             5.264396e+04   2021  200067767
#                                             5.288230e+04   2021  240700302
#                                             5.371402e+04   2021  240300558
#                                             8.382214e+04   2021  244301099
#                                             8.457553e+04   2021  200069169
# ...

# %% [markdown]
# # 2021 energy consumption per region

# %%
df2021[["libelle_regions", "consototale"]].groupby(by="libelle_regions").sum().sort_values(by="consototale", ascending=False)
# Out:
#                                               consototale
# libelle_regions
# Auvergne-Rhône-Alpes                         1.840461e+07
# Hauts-de-France                              1.568825e+07
# Occitanie                                    1.561919e+07
# Grand Est                                    1.117992e+07
# Bourgogne-Franche-Comté                      6.564454e+06
# Normandie                                    6.484553e+06
# Nouvelle-Aquitaine                           6.209959e+06
# Île-de-France                                6.133186e+06
# Bretagne                                     5.566557e+06
# Centre-Val de Loire                          4.995753e+06
# Pays de la Loire                             2.645408e+06
# Bretagne,Pays de la Loire                    1.772680e+06
# La Réunion                                   1.296506e+06
# Corse                                        7.138683e+05
# Guadeloupe                                   5.686313e+05
# ...

# %%
dfIdf = df.loc[df["libelle_regions"] == "Île-de-France"]

# %%
dfIdfYearlyConsumption = dfIdf[["annee", "consototale"]].groupby(by="annee").sum().sort_values(by="annee", ascending=False)
dfIdfYearlyConsumption = dfIdfYearlyConsumption.reset_index()

# %%
dfIdfYearlyConsumption
# Out:
#    annee   consototale
# 0   2022  8.462398e+06
# 1   2021  6.133186e+06
# 2   2020  8.540606e+06
# 3   2019  9.731235e+07
# 4   2018  1.289941e+06
# 5   2017  1.079170e+08
# 6   2016  2.604798e+07
# 7   2015  1.878326e+07
# 8   2014  2.064939e+07

# %%
import seaborn as sns

# %% [markdown]
# ## Energy consumption of IDF through years

# %%
sns.lineplot(data=dfIdfYearlyConsumption, x="annee", y="consototale")
# Out:
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='annee', ylabel='consototale'>

# %%
#df = df.groupby(by=["libelle_regions", "annee", "consototale"]).sum()
df["annee"].unique()
# Out:
# array([2021, 2022, 2020, 2015, 2019, 2016, 2018, 2014, 2013, 2017])

# %%
# select only interested column
df2 = df[["annee", "libelle_regions", "consototale"]]

# %%
dfConsYearNRegion = df2.groupby(by=["consototale"]).sum()
dfConsYearNRegion = dfConsYearNRegion.reset_index()
dfConsYearNRegion
# Out:
#        consototale  annee             libelle_regions
# 0     6.197010e+03   2014     Bourgogne-Franche-Comté
# 1     6.689000e+03   2015                      Guyane
# 2     7.274000e+03   2016                      Guyane
# 3     2.028577e+04   2015                   Occitanie
# 4     2.170502e+04   2017                   Grand Est
# ...            ...    ...                         ...
# 1995  1.944850e+07   2017        Auvergne-Rhône-Alpes
# 1996  2.050502e+07   2017                   Normandie
# 1997  4.058203e+07   2015  Provence-Alpes-Côte d'Azur
# 1998  7.444636e+07   2019               Île-de-France
# 1999  7.735929e+07   2017               Île-de-France
#
# [2000 rows x 3 columns]

# %% [markdown]
# ## List of all regions and islands energy consumption from 2014 to 2022

# %%
sns.lineplot(data=dfConsYearNRegion, x="annee", y="consototale", hue="libelle_regions")
# Out:
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df["libelle_regions"].unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Grand Est', 'Occitanie', 'Normandie',
#        'Nouvelle-Aquitaine', 'Centre-Val de Loire', 'Corse',
#        'Bourgogne-Franche-Comté', 'Bretagne', 'Bretagne,Pays de la Loire',
#        'Pays de la Loire', 'Hauts-de-France', 'Île-de-France',
#        'Martinique', 'La Réunion', 'Guadeloupe',
#        "Provence-Alpes-Côte d'Azur",
#        "Auvergne-Rhône-Alpes,Provence-Alpes-Côte d'Azur", 'Mayotte',
#        'Occitanie,Nouvelle-Aquitaine',
#        'Auvergne-Rhône-Alpes,Bourgogne-Franche-Comté',
#        'Normandie,Pays de la Loire', 'Nouvelle-Aquitaine,Occitanie',
#        'Normandie,Hauts-de-France', 'Guyane',
#        "Provence-Alpes-Côte d'Azur,Auvergne-Rhône-Alpes",
#        'Auvergne-Rhône-Alpes,Occitanie', 'Hauts-de-France,Normandie',
#        'Bourgogne-Franche-Comté,Auvergne-Rhône-Alpes',
#        'Bourgogne-Franche-Comté,Centre-Val de Loire',
#        'Centre-Val de Loire,Bourgogne-Franche-Comté',
# ...

# %% [markdown]
# ## Energy consumption per Regions in France

# %%
# select only the regions in france
selected_regions = ["Auvergne-Rhône-Alpes", "Grand Est", "Occitanie", "Normandie", "Nouvelle-Aquitaine", "Centre-Val de Loire", "Corse", "Bourgogne-Franche-Comté", "Bretagne", "Provence-Alpes-Côte d'Azur", "Pays de la Loire", "Île-de-France"]
filtered_dfConsYearNRegion = dfConsYearNRegion[dfConsYearNRegion['libelle_regions'].isin(selected_regions)]

sns.lineplot(data=filtered_dfConsYearNRegion, x="annee", y="consototale", hue="libelle_regions")
# Out:
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gonzalo/miniconda3/envs/env1/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# filter 2022
df2022 = filtered_dfConsYearNRegion[filtered_dfConsYearNRegion['annee'].isin([2022])].groupby(by=["libelle_regions", "annee"]).sum()

# filter 2021
df2021 = filtered_dfConsYearNRegion[filtered_dfConsYearNRegion['annee'].isin([2021])].groupby(by=["libelle_regions", "annee"]).sum()

# filter 2020
df2020 = filtered_dfConsYearNRegion[filtered_dfConsYearNRegion['annee'].isin([2020])].groupby(by=["libelle_regions", "annee"]).sum()

# %% [markdown]
# # Rank by regions 2020

# %%
df2020.sort_values(by="consototale", ascending=False)
# Out:
#                                    consototale
# libelle_regions            annee
# Normandie                  2020   4.734805e+07
# Auvergne-Rhône-Alpes       2020   1.938205e+07
# Grand Est                  2020   1.511110e+07
# Nouvelle-Aquitaine         2020   1.288662e+07
# Bretagne                   2020   1.194400e+07
# Occitanie                  2020   1.107871e+07
# Centre-Val de Loire        2020   8.803094e+06
# Île-de-France              2020   8.540606e+06
# Pays de la Loire           2020   7.629849e+06
# Provence-Alpes-Côte d'Azur 2020   6.966260e+06
# Bourgogne-Franche-Comté    2020   3.064440e+06
# Corse                      2020   3.531507e+05

# %% [markdown]
# # Rank by regions 2021

# %%
df2021.sort_values(by="consototale", ascending=False)
# Out:
#                                    consototale
# libelle_regions            annee
# Auvergne-Rhône-Alpes       2021   1.840461e+07
# Occitanie                  2021   1.561919e+07
# Grand Est                  2021   1.117992e+07
# Bourgogne-Franche-Comté    2021   6.564454e+06
# Normandie                  2021   6.484553e+06
# Nouvelle-Aquitaine         2021   6.209959e+06
# Île-de-France              2021   6.133186e+06
# Bretagne                   2021   5.566557e+06
# Centre-Val de Loire        2021   4.995753e+06
# Pays de la Loire           2021   2.645408e+06
# Corse                      2021   7.138683e+05
# Provence-Alpes-Côte d'Azur 2021   3.290008e+05

# %% [markdown]
# # Rank by regions 2022

# %%
df2022.sort_values(by="consototale", ascending=False)
# Out:
#                                    consototale
# libelle_regions            annee
# Auvergne-Rhône-Alpes       2022   1.918622e+07
# Grand Est                  2022   1.697433e+07
# Île-de-France              2022   8.462398e+06
# Normandie                  2022   6.867089e+06
# Nouvelle-Aquitaine         2022   3.269725e+06
# Occitanie                  2022   1.389642e+06
# Pays de la Loire           2022   1.157291e+06
# Bretagne                   2022   1.064749e+06
# Centre-Val de Loire        2022   7.963215e+05
# Bourgogne-Franche-Comté    2022   7.345990e+05
# Provence-Alpes-Côte d'Azur 2022   3.863050e+05
# Corse                      2022   4.237612e+04

# %%
# check if there is any missing data ?
